# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Evaluación 1 - Reconocimiento de patrones**
#
# Genere las siguientes imágenes usando recorridos por píxeles a partir de la [lena.jpg](https://drive.google.com/file/d/1gH5sJN__2g7f9ndLhLvTECdOBJIGUbg_/view?usp=sharing)

# %%
# Import some libraries
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ## **Ejercicio 1**
#
# Genere la siguiente imagen [resultado](https://drive.google.com/file/d/1-199t6nftWQoXFkp4JbVFUuHsTcedbyi/view?usp=sharing). \\
# **NOTA:** En la salida de la celda puede encontrar el tamaño de la imagen final.

# %%
# Lea la imagen
image = cv2.imread("/content/drive/MyDrive/Patrones/patrones-master/Evaluacion1/lena.jpg")
img_1 = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
print("Lena")
plt.imshow(img_1)
plt.show()
print('')

# Realice aquí todas las operaciones que necesite. Puede añadir cuantas celdas de código requiera
ROI = img_1[0:150,0:200,:]
ROI2 = img_1[0:150,200:400,:]
ROI3 = img_1[150:300,0:200,:]
ROI4 = img_1[150:300,200:400,:]
ROI2[:, :, 0] = 255
ROI3[:, :, 2] = 255
ROI4[:, :, 1] = 255

#print("Resultado1")
#plt.imshow(ROI)
#plt.show()
#print('')

#print("Resultado2")
#plt.imshow(ROI2)
#plt.show()
#print('')

#print("Resultado3")
#plt.imshow(ROI3)
#plt.show()
#print('')


#print("Resultado 4")
#plt.imshow(ROI4)
#plt.show()
#print('')

[Fl, Cl, Ch]=ROI.shape
Resultado_A=np.zeros((Fl,Cl,Ch))
Resultado_B=np.zeros((Fl,Cl,Ch))
Resultado_C=np.zeros((Fl,Cl,Ch))

for i in range(0, Fl, 1):
  for j in range(0, Cl, 1):
    for k in range(0, Ch, 1):
      Resultado_A[i,j,k]= ROI[i,j,k]+10
      Resultado_B[i,j,k]= ROI[i,j,k]-10

      if Resultado_A[i,j,k]>255:
         Resultado_A[i,j,k]=255

      if Resultado_B[i,j,k]<0:
         Resultado_B[i,j,k]=0

RFigura=np.ones((2*Fl+0,2*Cl+0,Ch))*255
RFigura[0:Fl,0:Cl,:]= ROI
RFigura[0:Fl,Cl+0:2*Cl+0,:]= ROI4
RFigura[Fl+0:2*Fl+0,0:Cl,:]= ROI2
RFigura[Fl+0:2*Fl+0,Cl+0:2*Cl+0,:]= ROI3

print('Imagen resultante')
plt.imshow(RFigura.astype('uint8'),vmin=0, vmax=255) 
plt.show()
print('')

# Muestre la imagen y guardela en drive usando opencv (consultar)
RFigura= cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
directory = r'/content/drive/MyDrive/Patrones/patrones-master/Evaluacion1'
New_filename= 'Lena_EJ_1.jpg'
os.chdir(directory)
#Guardando
cv2.imwrite(New_filename, RFigura)
# Out:
# Lena
# Imagen resultante
# True

# %% [markdown]
# ## **Ejercicio 2**
#
# Genere la siguiente imagen [resultado](https://drive.google.com/file/d/1-2ZabtbOJBg3liembLMzrwo9jWUcNdNW/view?usp=sharing). \\
# **NOTA:** En la salida de la celda puede encontrar el tamaño de la imagen final.

# %%
# Lea la imagen
image = cv2.imread ("/content/drive/MyDrive/Patrones/patrones-master/Evaluacion1/lena.jpg")
img=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
print("Lena")
plt.imshow(img)
plt.show()
print(img.shape)
print('')
# Realice aquí todas las operaciones que necesite. Puede añadir cuantas celdas de código requiera

ROI = img_1[0:150,0:400]
flip_lena = np.flipud(ROI)
img[150:300,0:400,:]= flip_lena
plt.imshow(img)
# Muestre la imagen y guardela en drive usando opencv (consultar)
img= cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
directory = r'/content/drive/MyDrive/Patrones/patrones-master/Evaluacion1'
New_filename= 'Lena_EJ_2.jpg'
os.chdir(directory)
#Guardando
cv2.imwrite(New_filename, img)
# Out:
# Lena
# (300, 400, 3)
# True

# %% [markdown]
# ## **Ejercicio 3**
#
# Genere la siguiente imagen [resultado](https://drive.google.com/file/d/1-7DL7XNLoZ850EyxbjsPN40-thoOUt58/view?usp=sharing). \\
# **NOTA:** En la salida de la celda puede encontrar el tamaño de la imagen final.

# %%
# Lea la imagen
image = cv2.imread("/content/drive/MyDrive/Patrones/patrones-master/Evaluacion1/lena.jpg")
img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
print(img.shape)
print('')

# Realice aquí todas las operaciones que necesite. Puede añadir cuantas celdas de código requiera
ROI = img[90:190,0:400]
width = ROI.shape[1]
height = 100
dim = (width, height)

resized = cv2.resize(ROI, dim, interpolation = cv2.INTER_AREA)
img[0:100,0:400,:]= ROI
img[200:300,0:400,:]= ROI
plt.imshow(img)
print(img.shape)
# Muestre la imagen y guardela en drive usando opencv (consultar)
img= cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
directory = r'/content/drive/MyDrive/Patrones/patrones-master/Evaluacion1'
New_filename= 'Lena_EJ_3.jpg'
os.chdir(directory)
#Guardando
cv2.imwrite(New_filename, img)
# Out:
# (300, 400, 3)
#
# (300, 400, 3)
# True

# %% [markdown]
# ## **Ejercicio 4**
#
# Genere la siguiente imagen [resultado](https://drive.google.com/file/d/1-9jWSwRb1ld_xN6iHTHVKT92bGat0I4s/view?usp=sharing). \\
# **NOTA:** En la salida de la celda puede encontrar el tamaño de la imagen final.

# %%
# Lea la imagen
image = cv2.imread("/content/drive/MyDrive/Patrones/patrones-master/Evaluacion1/lena.jpg")
img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
print("Image")
plt.imshow(img)
plt.show()
print('')

# Realice aquí todas las operaciones que necesite. Puede añadir cuantas celdas de código requiera
ROI = ROI = img[90:190,160:260]
#----SUPERIOR------
img[0:100,0:100]= ROI
img[0:100,100:200]= ROI
img[0:100,200:300]= ROI
img[0:100,300:400]= ROI

#----MITAD----
ROI_2 =  img[0:100,0:400]
img[100:200,0:400]= ROI_2

#----INFERIOR----
img[200:300,0:400]= ROI_2

print("image with ROI")
print(img.shape)
plt.imshow(img)
plt.show()

# Muestre la imagen y guardela en drive usando opencv (consultar)
img= cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
directory = r'/content/drive/MyDrive/Patrones/patrones-master/Evaluacion1'
New_filename= 'Lena_EJ_4.jpg'
os.chdir(directory)
#Guardando
cv2.imwrite(New_filename, img)
# Out:
# Image
# image with ROI
# (300, 400, 3)
# True

# %% [markdown]
# ## **Ejercicio 5**
#
# Genere la siguiente imagen [resultado](https://drive.google.com/file/d/1-B7q4mrI5RqLDFPm0kJS8BClpKRiCcge/view?usp=sharing). Para esto, use la imagen de [Baboon.png](https://drive.google.com/file/d/1FaFhZvB3Iom32ZP8yQIfBDnKQiKxspAz/view?usp=sharing). \\
# **NOTA:** En la salida de la celda puede encontrar el tamaño de la imagen final.

# %%
# Lea la imagen
image = cv2.imread("/content/drive/MyDrive/Patrones/patrones-master/Evaluacion1/lena.jpg")
img_1 = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
print("Lena")
plt.imshow(img_1)
plt.show()
print('')

baboon = cv2.imread("/content/drive/MyDrive/Patrones/patrones-master/Evaluacion1/Baboon.png")
img_2 = cv2.cvtColor(baboon, cv2.COLOR_BGR2RGB)
width = 100
height = 100
dim = (width, height)
plt.imshow(img_2)
plt.show()
print('')

# Realice aquí todas las operaciones que necesite. Puede añadir cuantas celdas de código requiera
resized = cv2.resize(img_2, dim, interpolation = cv2.INTER_AREA)
img_1[100:200,160:260]= resized
print(img_1.shape)
plt.imshow(img_1)
plt.show()

# Muestre la imagen y guardela en drive usando opencv (consultar)
imgs= cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
directory = r'/content/drive/MyDrive/Patrones/patrones-master/Evaluacion1'
New_filename= 'Lena_EJ_5.jpg'
os.chdir(directory)
#Guardando
cv2.imwrite(New_filename, imgs)
# Out:
# Lena
# (300, 400, 3)
# True

# %% [markdown]
# ## **Ejercicio 6**
#
# Cree una función que tome el nombre de un archivo con su extensión en formato string y retorne una tupla en el qué, la primera posición sea el nombre del archivo y la segunda la extensión. \\
# **NOTA:** NO use splitext ni similares.

# %%
from prompt_toolkit.eventloop.coroutine import Return
path = cv2.imread ("/content/drive/MyDrive/Patrones/patrones-master/Evaluacion1")

#----Primero observemos los archivos que tenemos en la mira para identificar y separar-----
for file in os.listdir(path):
 print (file)
if file.count ('.')>1:
   Arch = file
else:
  check= file.find('.')
  ext = file [check:]
  nom = file [:check]
  Arch = (nom,ext)
  
return Arch
print(takepathfile('/content/drive/MyDrive/Patrones/patrones-master/Evaluacion1/Baboon.png'))
# Out:
# lena.jpg
# Lena_EJ_1.jpg
# Baboon.png
# E1_images (1).ipynb
# Lena_EJ_2.jpg
# Lena_EJ_3.jpg
# Lena_EJ_4.jpg
# Lena_EJ_5.jpg
#   File "<ipython-input-62-ef96f2010e1b>", line 15
#     return Arch
#                ^
# SyntaxError: 'return' outside function
